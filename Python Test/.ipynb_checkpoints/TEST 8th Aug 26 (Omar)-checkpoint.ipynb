# %%
score = 0

print("Q.1: What is the capital of Pakistan?")
print("A. Lahore")
print("B. Karachi")
print("C. Islamabad")
print("D. Peshawar")

answer = input("Answer: ")

if answer.upper() == "C":
    print("Correct!")
    score += 1
else:
    print("Wrong!")

print("Q. 2: How many province in Pakistan?")
print("A. 2")
print("B. 3")
print("C. 4")
print("D. 5")

answer = input("Answer: ")

if answer.upper() == "C":
    print("Correct!")
    score += 1
else:
    print("Wrong!")


print("Q.3: How many days are there in a week?")
print("A. 5")
print("B. 6")
print("C. 7")
print("D. 8")

answer = input("Answer: ")

if answer.upper() == "C":
    print("Correct!")
    score += 1
else:
    print("Wrong!")


print("Q.4: Which one is a programming language?")
print("A. Python")
print("B. Windows")
print("C. Google")
print("D. Chrome")

answer = input("Answer: ")

if answer.upper() == "A":
    print("Correct!")
    score += 1
else:
    print("Wrong!")


print("Q.5: What is 10 + 5?")
print("A. 10")
print("B. 15")
print("C. 20")
print("D. 25")

answer = input("Answer: ")

if answer.upper() == "B":
    print("Correct!")
    score += 1
else:
    print("Wrong!")

print("Quiz Finished!")
print("Total Score:", score, "/ 5")

if score >3:
    print("EXCELENT")
else:
    print("Good Try")
# Out:
# Q.1: What is the capital of Pakistan?
# A. Lahore
# B. Karachi
# C. Islamabad
# D. Peshawar
# Answer:
# Wrong!
# Q. 2: How many province in Pakistan?
# A. 2
# B. 3
# C. 4
# D. 5
# Answer:
# Wrong!
# Q.3: How many days are there in a week?
# A. 5
# B. 6
# C. 7
# D. 8
# Answer:
# Wrong!
# Q.4: Which one is a programming language?
# A. Python
# B. Windows
# C. Google
# D. Chrome
# Answer:
# Wrong!
# Q.5: What is 10 + 5?
# A. 10
# B. 15
# C. 20
# D. 25
# Answer:
# Wrong!
# Quiz Finished!
# Total Score: 0 / 5
# Good Try
